# %% [markdown]
# <a href="https://colab.research.google.com/github/basantyoussry/Crypto-Currency-/blob/main/Crypto_Currency_Bassant.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/DailyDelhiClimateTrain.csv', header=0)

# %%
df
# Out:
#             date   meantemp    humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...          ...        ...         ...         ...           ...
# 1457  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461  2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   object
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 57.2+ KB

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             date   meantemp    humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...          ...        ...         ...         ...           ...
# 1457  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461  2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]>

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df
# Out:
#            date   meantemp    humidity  wind_speed  meanpressure
# 0    2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1    2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2    2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3    2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4    2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...         ...        ...         ...         ...           ...
# 1457 2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458 2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459 2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460 2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461 2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   datetime64[ns]
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 57.2 KB

# %%
df.set_index('date',inplace=True)

# %%
df
# Out:
#              meantemp    humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...               ...         ...         ...           ...
# 2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 4 columns]

# %%
df.plot(figsize=(10,10))
# Out:
# <Axes: xlabel='date'>

# %%
df[['humidity']].plot(figsize=(10,10))
# Out:
# <Axes: xlabel='date'>

# %%
df[['humidity']].plot(figsize=(10,10))
# Out:
# <Axes: xlabel='date'>

# %%
df.isnull().value_counts()
# Out:
# meantemp  humidity  wind_speed  meanpressure
# False     False     False       False           1462
# dtype: int64

# %%
df.isnull().sum()
# Out:
# meantemp        0
# humidity        0
# wind_speed      0
# meanpressure    0
# dtype: int64

# %%
df.shape
# Out:
# (1462, 4)

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import colors
from matplotlib.ticker import PercentFormatter


# Creating dataset

N_points = 10000
n_bins = 20

# Creating distribution
# x = np.random.randn(N_points)
# y = .8 ** x + np.random.randn(10000) + 25
legend = ['distribution']

# Creating histogram
fig, axs = plt.subplots(1, 1,
						figsize =(10, 7),
						tight_layout = True)


# Remove axes splines
for s in ['top', 'bottom', 'left', 'right']:
	axs.spines[s].set_visible(False)

# Remove x, y ticks
axs.xaxis.set_ticks_position('none')
axs.yaxis.set_ticks_position('none')

# Add padding between axes and labels
axs.xaxis.set_tick_params(pad = 5)
axs.yaxis.set_tick_params(pad = 10)

# Add x, y gridlines
axs.grid(
		linestyle ='-.', linewidth = 0.5,
		alpha = 0.6)

# Add Text watermark
fig.text(0.9, 0.15, 'Crypto Currency',
		fontsize = 12,
		color ='red',
		ha ='right',
		va ='bottom',
		alpha = 0.7)

# Creating histogram
N, bins, patches = axs.hist(df, bins = n_bins)

# Setting color
fracs = ((N**(1 / 5)) / N.max())
norm = colors.Normalize(fracs.min(), fracs.max())

for thisfrac, thispatch in zip(fracs, patches):
	color = plt.cm.viridis(norm(thisfrac))


# Adding extra features
plt.xlabel("X-axis")
plt.ylabel("y-axis")
plt.legend(legend)
plt.title('Customized histogram')

# Show plot
plt.show()

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# from matplotlib import colors
# from matplotlib.ticker import PercentFormatter

# # Creating dataset
# # np.random.seed(23685752)
# N_points = 10000
# n_bins = 20

# # Creating distribution
# x = df
# y =df['time']

# # Creating histogram
# fig, axs = plt.subplots(1, 1,
# 						figsize =(10, 10),
# 						tight_layout = True)

# axs.hist(x, bins = n_bins)

# # Show plot
# plt.show()

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'meantemp'}>,
#         <Axes: title={'center': 'humidity'}>],
#        [<Axes: title={'center': 'wind_speed'}>,
#         <Axes: title={'center': 'meanpressure'}>]], dtype=object)

# %%
import seaborn as sns
sns.kdeplot(data = df[['meantemp', 'humidity', 'wind_speed', 'meanpressure']])
# Out:
# <Axes: ylabel='Density'>

# %%
plt.xticks(rotation=90)
plt.plot(df['meantemp'])

# %%
plt.xticks(rotation=90)
plt.plot(df['humidity'])

# %%
import pandas as pd
from statsmodels.tsa.stattools import adfuller

# Assuming you have a time series data stored in a pandas DataFrame called 'data'
# with a column named 'value' containing the values

# Step 1: Prepare the data
values = df['wind_speed'].values

# Step 2: Perform the ADF test
result = adfuller(values)

# Step 3: Interpret the results
adf_statistic = result[0]
p_value = result[1]
critical_values = result[4]

print(f'ADF Statistic: {adf_statistic}')
print(f'p-value: {p_value}')
print('Critical Values:')
for key, value in critical_values.items():
    print(f'\t{key}: {value}')
# Out:
# ADF Statistic: -3.838096756685109
# p-value: 0.0025407221531463645
# Critical Values:
# 	1%: -3.434908816804013
# 	5%: -2.863553406963303
# 	10%: -2.5678419239852994

# %%
# p_value = result[1]
# values = df['meanpressure'].values

# # Step 2: Perform the ADF test
# result = adfuller(values)
# print(f'p-value: {p_value}')

# %%
p_value = result[1]
values = df['meantemp'].values

# Step 2: Perform the ADF test
result = adfuller(values)
print(f'p-value: {p_value}')
# Out:
# p-value: 0.0025407221531463645

# %%
# values = df['humidity'].values

# # Step 2: Perform the ADF test
# result = adfuller(values)

# # Step 3: Interpret the results
# adf_statistic = result[0]
# p_value = result[1]
# critical_values = result[4]

# print(f'ADF Statistic: {adf_statistic}')
# print(f'p-value: {p_value}')
# print('Critical Values:')
# for key, value in critical_values.items():
#     print(f'\t{key}: {value}')

# %%
sns.lineplot(df['meantemp'])
# Out:
# <Axes: xlabel='date', ylabel='meantemp'>

# %%
df['meantemp'].values
# Out:
# array([10.        ,  7.4       ,  7.16666667, ..., 14.0952381 ,
#        15.05263158, 10.        ])

# %%
square_root_df = df.copy()
square_root_df['meantemp'] = square_root_df['meantemp'].values ** (1/2)

# %%
square_root_df.drop(['humidity',	'wind_speed',	'meanpressure'], axis = 1, inplace = True)

# %%
plt.plot(square_root_df)
plt.show()

# %%
# plt.title("Sqaure Root Mean Temprature Over Days")
# plt.plot(square_root_df)

# %%
def adfuller_test(sales):
    result=adfuller(sales)
    labels = ['ADF Test Statistic','p-value','#Lags Used','Number of Observations']
    for value,label in zip(result,labels):
        print(label+' : '+str(value) )

if result[1] <= 0.05:
    print("strong evidence against the null hypothesis(Ho), reject the null hypothesis. Data is stationary")
else:
    print("weak evidence against null hypothesis,indicating it is non-stationary ")

adfuller_test(square_root_df['meantemp'])
# Out:
# weak evidence against null hypothesis,indicating it is non-stationary
# ADF Test Statistic : -3.0715011409334
# p-value : 0.02873538786642193
# #Lags Used : 5
# Number of Observations : 1456

# %%
# df['meantemp'] = df['meantemp'] - df['meantemp'].shift(1)
# df['Seasonal_diff']     = df['meantemp']-df['meantemp'].shift(12)
# df.head()
# Out:
#             meantemp   humidity  wind_speed  meanpressure  Seasonal_diff
# date
# 2013-01-01       NaN  84.500000    0.000000   1015.666667            NaN
# 2013-01-02 -2.600000  92.000000    2.980000   1017.800000            NaN
# 2013-01-03 -0.233333  87.000000    4.633333   1018.666667            NaN
# 2013-01-04  1.500000  71.333333    1.233333   1017.166667            NaN
# 2013-01-05 -2.666667  86.833333    3.700000   1016.500000            NaN

# %%
# df['Clos Difference'] = df['close'] - df['close'].shift(-1)
# df['Seasonal First Difference']=df['close']-df['close'].shift(12)
# df.head()

# %%
# adfuller_test(df['meantemp'].dropna())
# Out:
# ADF Test Statistic : -16.378720267074673
# p-value : 2.764863137594644e-29
# #Lags Used : 9
# Number of Observations : 1451

# %%
# p_value = result[1]
# values = df['meantemp'].values

# # Step 2: Perform the ADF test
# result = adfuller(values)
# # print(f'p-value: {p_value}')
# Out:
# ---------------------------------------------------------------------------
# MissingDataError                          Traceback (most recent call last)
# <ipython-input-34-8839847f9939> in <cell line: 5>()
#       3
#       4 # Step 2: Perform the ADF test
# ----> 5 result = adfuller(values)
#       6 print(f'p-value: {p_value}')
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     319
#     320         if not regresults:
# --> 321             icbest, bestlag = _autolag(
#     322                 OLS, xdshort, fullRHS, startlag, maxlag, autolag
#     323             )
#
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/stattools.py in _autolag(mod, endog, exog, startlag, maxlag, method, modargs, fitargs, regresults)
#     127     method = method.lower()
#     128     for lag in range(startlag, startlag + maxlag + 1):
# --> 129         mod_instance = mod(endog, exog[:, :lag], *modargs)
# ...

# %%
df['meantemp'].plot()

# %%
# from pandas.plotting import autocorrelation_plot
# autocorrelation_plot(df['meantemp'])
# plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
import statsmodels.api as sm
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(square_root_df['meantemp'].dropna(),lags=40,ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(square_root_df['meantemp'].dropna(),lags=40,ax=ax2)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
import pandas as pd
import statsmodels.api as sm

# Assuming you have a time series data stored in a pandas DataFrame called 'df'
# with a column named 'meantemp' containing the temperature values

# Step 1: Prepare the data
# df['meantemp'] = pd.to_numeric(square_root_df['meantemp'], errors='coerce')

# Step 2: Drop rows with missing values, if necessary
# df = square_root_df.dropna(subset=['meantemp'])

# Step 3: Create the ARIMA model
# values = square_root_df['meantemp']
model = sm.tsa.arima.ARIMA(square_root_df, order=(1, 0, 0))

# Step 4: Fit the model
results_ARIMA = model.fit()

# Step 5: Print the model summary
print(results_ARIMA.summary())
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
#                                SARIMAX Results
# ...
# Dep. Variable:               meantemp   No. Observations:                 1462
# Model:                 ARIMA(1, 0, 0)   Log Likelihood                 509.124
# Date:                Tue, 08 Aug 2023   AIC                          -1012.248
# Time:                        12:09:04   BIC                           -996.386
# ...

# %%
# import statsmodels.api as sm

# # Assuming you have a time series data stored in a pandas DataFrame called 'df'
# # with a column named 'value' containing the values

# # Step 1: Prepare the data
# values = df['meantemp']

# # Step 2: Create the ARIMA model
# model = sm.tsa.arima.ARIMA(values, order=(5, 3,3))

# # Step 3: Fit the model
# results_ARIMA = model.fit()

# # Step 4: Print the model summary
# print(results_ARIMA.summary())

# %%
# import pandas as pd
# import statsmodels.api as sm

# # Assuming you have a time series data stored in a pandas DataFrame called 'df'
# # with a column named 'value' containing the values

# # Step 1: Prepare the data
# values = df['meantemp']

# # Step 2: Create and fit the ARIMA model
# model = sm.tsa.arima.ARIMA(values, order=(1, 0, 0))
# results_ARIMA = model.fit()

# # Step 3: Make predictions
# start = 90
# # end = 103
# predicted_values = results_ARIMA.predict(start=start, end=end, dynamic=True, typ='levels')

# # Step 4: Assign the predictions to the 'volume' column
# df['predicted values'] = predicted_values

# # Step 5: Print the updated DataFrame
# print(df)

# %%
from statsmodels.tsa.arima_model import ARIMA
model= sm.tsa.arima.ARIMA(values, order=(0,1,0))
# model_fit=model.fit()
model_fit.summary()
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# /usr/local/lib/python3.10/dist-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency D will be used.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:               meantemp   No. Observations:                 1462
# Model:                 ARIMA(1, 0, 0)   Log Likelihood                 509.124
# Date:                Tue, 08 Aug 2023   AIC                          -1012.248
# ...

# %%
# df['predicted']=model_fit.predict(start=2017,dynamic=True)
predicted = model_fit.forecast(12*30)
# df[['meantemp','predicted']].plot(figsize=(12,8))
plt.plot(square_root_df)
plt.plot(predicted)
plt.show()

# %%
# import statsmodels.api as sm
# model=sm.tsa.statespace.SARIMAX(df['meantemp'],order=(0,1, 1))
# results=model.fit()
# df['predticed']=results.predict(start=400,dynamic=True)
# df[['meantemp','predticed']].plot(figsize=(12,8))

# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from tensorflow.keras.optimizers import Adam

# Assuming you have a time series data stored in a pandas DataFrame called 'data'
# with a column named 'value' containing the values

# Step 1: Prepare the data
values = square_root_df['meantemp'].values.reshape(-1, 1)

# %%
def convertToMatrix(data, step):
    X, Y =[], []
    for i in range(len(data)-step):
        d=i+step
        X.append(data[i:d,])
        Y.append(data[d,])
    return np.array(X), np.array(Y)[: , -1]

# %%
features, targets = convertToMatrix(np.array(values), 7)
print(features.shape)
print(targets.shape)
# Out:
# (1455, 7, 1)
# (1455,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test,y_train, y_test = train_test_split(features,targets ,random_state=104, test_size=0.25, shuffle=True)

# %%
# Normalize the data
scaler = MinMaxScaler()
scaled_values = scaler.fit_transform(values)

# Split the data into training and testing sets
train_size = int(len(scaled_values) * 0.8)
train_data = scaled_values[:train_size]
test_data = scaled_values[train_size:]

# Step 2: Create the LSTM model
model = Sequential()
model.add(LSTM(64))
model.add(Dense(1))

# Step 3: Compile the model
model.compile(optimizer=Adam(learning_rate=0.001), loss='mean_squared_error')

# Step 4: Train the model
model.fit(X_train, y_train, epochs=20, batch_size=1, verbose=2)

# Step 5: Make predictions
train_predictions = model.predict(X_train)
test_predictions = model.predict(X_test)

# # Step 6: Inverse transform the predictions
# train_predictions = scaler.inverse_transform(train_predictions)
# test_predictions = scaler.inverse_transform(test_predictions)

# Step 7: Evaluate the model (optional)
# You can evaluate the model performance using various metrics like RMSE, MAE, etc.

# Print the predictions
print("Train Predictions:")
print(train_predictions)
print("Test Predictions:")
print(test_predictions)
# Out:
# Epoch 1/20
# 1091/1091 - 10s - loss: 0.3988 - 10s/epoch - 9ms/step
# Epoch 2/20
# 1091/1091 - 4s - loss: 0.0568 - 4s/epoch - 4ms/step
# Epoch 3/20
# 1091/1091 - 4s - loss: 0.0529 - 4s/epoch - 4ms/step
# Epoch 4/20
# 1091/1091 - 4s - loss: 0.0479 - 4s/epoch - 4ms/step
# Epoch 5/20
# 1091/1091 - 4s - loss: 0.0427 - 4s/epoch - 3ms/step
# Epoch 6/20
# 1091/1091 - 3s - loss: 0.0411 - 3s/epoch - 3ms/step
# Epoch 7/20
# 1091/1091 - 5s - loss: 0.0375 - 5s/epoch - 4ms/step
# Epoch 8/20
# 1091/1091 - 5s - loss: 0.0394 - 5s/epoch - 5ms/step
# Epoch 9/20
# 1091/1091 - 4s - loss: 0.0371 - 4s/epoch - 4ms/step
# Epoch 10/20
# 1091/1091 - 6s - loss: 0.0377 - 6s/epoch - 5ms/step
# Epoch 11/20
# 1091/1091 - 5s - loss: 0.0356 - 5s/epoch - 4ms/step
# Epoch 12/20
# 1091/1091 - 6s - loss: 0.0353 - 6s/epoch - 6ms/step
# Epoch 13/20
# 1091/1091 - 6s - loss: 0.0350 - 6s/epoch - 5ms/step
# Epoch 14/20
# 1091/1091 - 7s - loss: 0.0357 - 7s/epoch - 6ms/step
# Epoch 15/20
# ...

# %%
s = len(square_root_df.index) - int((len(square_root_df.index))*0.25)
s
# Out:
# 1097

# %%
test_predictions.shape
# Out:
# (364, 1)

# %%
len(square_root_df.index[s:-1])
# Out:
# 364

# %%
plt.plot(square_root_df.index[s:-1], y_test)
plt.plot(square_root_df.index[s:-1], test_predictions)
